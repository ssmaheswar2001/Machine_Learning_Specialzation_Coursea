# %% [markdown]
# # Making Recommendations
# - ![image.png](attachment:image.png)

# %% [markdown]
# # Using per-item features
# - In this model we can for user j, we can predict user j's rating for movie i as w(j).X(i)+b(j). So here the parameters w(j) and b(j) are the parameters used to predict user j's rating for movie i which is a function of X(i), which is the feature of movie i. And this is a lot like linear regression, except that we're fitting a different linear regression model for each of the users in the dataset.
# - ![image-2.png](attachment:image-2.png)
# - The model we have is for user j and movie i predict the rating to be w(j).X(i) + b(j). So what we'd like to do is to learn the parameters w(j) and b(j), given the data that we have. That is given the ratings a user has given of a set of movies.
# - ![image-3.png](attachment:image-3.png)
# - ![image-4.png](attachment:image-4.png)
# - We're training a different linear regression model for each of the users. So that's how we can learn parameters and predict movie rating, if we has access to these features X1 and X2. But where do these features come from? anf what if we don't have access to such features that give us enough detail about the movies with which to make these predictions?

# %% [markdown]
# # Collaborative Filtering algorithm
# - If we have features for each movie such as features x_1 and x_2 that tell us how much is a movie romance movie and how much is this an action movie. Then we can use basically linear regression to learn to predict movie ratings. But what if we don't have those features X_1, X_2?
# - ![image.png](attachment:image.png)
# - In collaborative filtering, becase we have ratings from multiple user of the same item with the same movie. That's what makes it possible to try to guess what are possible values for these features.
# - If we have parameters w and b, all the users, then minimizing the cost function as a function of x_1 through x_nm using gradient descent or some other algorithm, this will actually allow us to take a pretty good guess at learning good features for the movies.
# - ![image-2.png](attachment:image-2.png)
# - We have assumed we had those parameters w and b for the different user. Where do we get those parameters from?
# - ![image-3.png](attachment:image-3.png)
# - ![image-4.png](attachment:image-4.png)
# - We minimize the cost function as a function of all three of the sets of parameters w, b and also x.

# %% [markdown]
# # Binary Labels : Favs, likes and clicks
# - Many important applications of recommender systems or collective filtering algorithms involved binary labels where instead of a user giving us a 1 to 5 star or o to 5 star rating, they just somehow gives us a sense of they like this item or they didn't like the item.
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
# - This is is just like the logistic regression
# - ![image-3.png](attachment:image-3.png)
# - In order to builf the algorithm, we'll also have to modify the cost function from sqaured error cost function to the cost function to the cost function that is more appropriate for binary labels for a logistic regression like model like binrary cross entropy cost function.
#     ![image-4.png](attachment:image-4.png)
