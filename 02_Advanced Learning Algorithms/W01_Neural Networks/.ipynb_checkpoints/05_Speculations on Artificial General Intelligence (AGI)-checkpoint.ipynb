# %% [markdown]
# - AI actually includes 2 very differen things
# 1. Artificial narrow intelligence (ANI)
#     - An AI system that does one thing, a narrow task, sometimes really well and can be incredibly vluable, such as smart speaker or self-driving car or web search
# 2. Artificial General Intelligence (AGI)
#     - There's hope of building AI system that could do anything a typical human can do.
# - ![image.png](attachment:image.png)
# - ![image-3.png](attachment:image-3.png)
# - ![image-2.png](attachment:image-2.png)
