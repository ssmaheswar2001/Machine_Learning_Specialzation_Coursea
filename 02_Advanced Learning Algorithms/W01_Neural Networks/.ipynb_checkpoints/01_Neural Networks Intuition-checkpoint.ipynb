# %% [markdown]
# # Welcome
# - Neurall networks, also called deep specialization.
# - When we're building a practical machine learning system, there are a lot of we have to maeke, such as should us spend more time collectin data or should we buy a much bigger GPU to build a  much bigger nerual network?
# - If we go to the internet and download the parameters of a neural network that someone else has trained and whose parameters that posted on internet, then to use that neural network to make predictions would be called inference.
# - ![image.png](attachment:image.png)

# %% [markdown]
# # Neural Networks Intuition
# - ![image.png](attachment:image.png)
# - What a neurson does is it takes some inputs, one or more inputs, which are just numbers. It does some computation and it outputs some other number, which then could be an input to a second neuron
# - ![image-2.png](attachment:image-2.png)
# - If we train a large-size neural networks, the perfomance will be higher
#     ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Demand Prediction
# - We'll use an example from demand prediction in which we look at the product and try to predict, will this product be a top seller or not?
# - Alphabet 'a' is used to denote the output of the algorithm.
# - The term 'a' stands for activation, and it's actually a term from neuroscience, and it refers to how much a neuron is sending a high output to other neurons downstream from it.
# - It turns out that the logistic regression units or this little logistic regression algorithm, can be thought of as a very simplified model of a single neuron in the brain.
# - Where what the neurson does is it takes us input the price x, and then it computes this logistic regression sigmoid function on top and it outputs the number a. This is single unit.
# - ![image.png](attachment:image.png)
# - Building a neural network is just requires taking a bunch of these neurons and wiring them together or putting them together.
# - A layer is a grouping of neurons which takes as input the same or similar features, and that in turn outputs a few numbers together.
# - These llayers can have multiple neurons or it can also have a single neuron.
# - The inner layers (affordability, awarness and preceive quality) are called activations.
# - ![image-2.png](attachment:image-2.png)
# - Here as decribed, we had to go through the neurons one at a time and decide what inputs it would take from the previous layer. But, if we're building a large neural network it'd be a lot of work to go through manually decide which neurons should takw hich features as inputs. The way a neural network is implemented in pracitice each neuron in a certain layer, will have access to every feature, to every value from the previous layer, from the input layer which is why arrows from every input features to every one of these neurons.
# - ![image-3.png](attachment:image-3.png)
# - What the neural network does is instead os us needing to manually engineer the features, it can learn its own features to make the learning problem easier for itself.
# - ![image-4.png](attachment:image-4.png)
# - When we're building our own neural network, one of the decisions we need to make is how many hidden layers do we want and how many neurons do we want each hidden layer to have.
# - Choosing the right number of hidden layers and number of hiddern units per layer can have an impact on the performance of a learnig algorithm as well.
# - Multiple layers like this called a multilayer perceptron.

# %% [markdown]
# ## Example : Recognizing images
# - ![image.png](attachment:image.png)
# - The input image X is fed to the layer of neurons.
# - One intresting thing would be if we look at a neural network that's been trained on a lot of images of faces and to try to visualize what are these hidden layers, trying to compute. It turns out that when we train a system like on a lot of pictures of faces and we peer at the different neurons in the hidden layers to figure out what they may be computing this is what we might find.
# - In the first layer, we might find one neuron that is looking for the low vertical line or a vertical edge. A second neuron looking for a oriented line or oriented edge. the third neurons looking for a line ar that orientation, and so on.
# - In the earliest layers of a neural network, we might find that the neurons are looking for very short lines or very short edges in the image. If we look at the next hidden layer, we find that these neurons might learn to group together lots of little short lines and little short edge segments inorder to look for parts of faces.
# - Then finnaly, detecting how much the face corresponding to different face shapes creates a rich set of features that then helps the output layer try to determine the identity of the person picture.
# - A remarkable thing about the neural network is we can learn these featutes detectors at the different hidden layer all by itself.
# - For example, no one ever told it to look for short little edges in the first layer, and eyes and noses and face parts in the second layer and then more complete face shapes at third layer. The neural network is able to figure out these things all by itseld from the data.
# - The neurons in the first hidden layer are shown looking at relatively small windows to look for the edges. In the second hidden layer is looking at bigger window, and the thirs hidden layer is looking at even bigger window. Thes little neurons visualarizations actually corresponding to differntly sized regions in the image.
# - ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)
