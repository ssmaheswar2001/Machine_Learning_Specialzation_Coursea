# %% [markdown]
# # Additional Optimization
# - Gradient descent is an optimization algorithnm that is widely used in machine learning, and was the founation of many algorithms like linear regression and logistic regression and implementations of neural networks.
# - But it turns out that there are now some other optimizations algorithms for minimizing the cost function, that tare even better than gradient descent.
# - Why don;t we make Alpha bigger in gradient descent, can we have an algorithm to automatically increase Alpha? They ust make it take bigger steps and get to minimum faster. There's an algorithm called Adam Algorithm that can do that. If it sees that the learning rate is too small, and we are just taking tiny little steps in a similar direction over and over, we should just make the learning rate Alpha bigger. The Adam algorithm can alos do smaller learning rate, we can take a more smooth path towards the minimum of the cost function.
# - Depening on how gradient desecent is proceeding, sometimes we wish us had a bigger learning rate Alpha, and sometimes we wish we had a smaller learning rate Alpha. The Adam algorithm can adust the learning rate automatically.
# - Adam stands for Adaptive Moment Estimation
# - ![image.png](attachment:image.png)
# - The Adam algorithm doesn't use a single global learning rate Alpha. It uses a different learning rates for every single parameter of our model. If we have parameters w_1 through w_10 as was b then it actually has 11 learning rate parameters.
#     ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Additional Layer Types
# - The dense layer type in which every neuron in the layer gets its inputs all the activations from the previous layer.
# - The dense layer that we've been using the activation of a neuron in say the 2nd hidden layer is a function of every single activation value from the previous layer of a one.
#     ![image.png](attachment:image.png)
# - One other layer type that we may see in some work is called a convolutional layer.
# - The type of layer where each neuron only looks at a region of the input image is called a convolutional layer
# - ![image-2.png](attachment:image-2.png)
# - If we have multiple convolutional layers in a neural network sometimes that's called a convolutional neural network.
# - EKG signal to classify say whether the patient has a hear disease or some diagnosable heart conditions. Ee have 100 inputs X_1 to X_100. So, hen we construct the first hidden layer instead of jhaving the first hidden unit take us input all 100. The first hidden unit look at only X_1 through X_20. So that corresponds to looking at just a small window of the EKG signal. The 2nd hidden unit looks at X_11 through X_30  and so on. So it looks like a small window towards the end of this EKG time series.
# - This is a convolutinal layer because these units in this layer look at only a limited window of the input. Now the new layer of the neural network has 9 units. The next layer can also be a convolutional layer.
# - In the 2nd hidden layer, let the first hidden unit looks at first 5 activations from the previous layer. The second unit in the 2nd hidden they may look at just another 5 numbers (A3-A7) and the final layer will only look at A5 through A9.
# - This is the example of a neural network with the first hidden layer being a convolutinal layer. the second hidden layer also being a convolutional layer and then the output layer being a sigmoid layer
#      ![image-3.png](attachment:image-3.png)
# - With the convolutional layers we have many architecture choice such as how big is the window of inputs that a single neuron should look at and how many neurons should layer have
